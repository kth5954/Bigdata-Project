# %%
import pandas as pd

# %%
filenamepd.read_csv("new/mov_19.csv")
# Out:
#    Unnamed: 0           name        date           sales  sales_share  \
# 0           0      신과함께-인과 연    2018.8.1  102,666,146,909        5.7%
# 1           1    어벤져스: 인피니티워   2018.4.25   99,919,006,769        5.5%
# 2           2       보헤미안 랩소디  2018.10.31   80,010,440,345        4.4%
# 3           3   미션 임파서블: 폴아웃   2018.7.25   55,888,375,112        3.1%
# 4           4      신과함께-죄와 벌  2017.12.20   47,348,157,705        2.6%
# 5           5  쥬라기 월드: 폴른 킹덤    2018.6.6   49,770,711,037        2.8%
# 6           6       앤트맨과 와스프    2018.7.4   47,465,443,185        2.6%
# 7           7            안시성   2018.9.19   46,335,334,026        2.6%
# 8           8          블랙 팬서   2018.2.14   45,883,143,457        2.5%
# 9           9         완벽한 타인  2018.10.31   44,350,807,074        2.5%
#
#   boxoffice_num screen rep_nation nation                      distributor  \
# 0    12,274,996  2,235         한국     한국                롯데컬처웍스(주)롯데엔터테인먼트
# ...
